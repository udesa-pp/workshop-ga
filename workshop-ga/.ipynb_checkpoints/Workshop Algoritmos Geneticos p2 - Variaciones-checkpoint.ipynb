# %% [markdown]
# Workshop Algoritmos Geneticos p2 - Variaciones
# ========================================
#
# En esta parte del workshop vamos a ver algunas variaciones en la implementación de este tipo de algoritmos y sus implicaciones.
#
# Para esto vamos a usar la librería [PyGAD](https://pygad.readthedocs.io/en/latest/).
#
# Repasando el enunciado del problema del viajante (aka Travelling Salesman Problem o TSP) tenemos lo siguiente dada una lista de ciudades:
# - Se debe empezar y terminar en la misma ciudad
# - Cualquier otra ciudad se puede visitar solo una vez
# - Se busca minimizar la distancia recorrida entre las mismas recorriendo todas ells

# %% [markdown]
# Algoritmo de PyGADD:
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import math
import numpy as np
import random
import pygad
from datetime import datetime
import matplotlib.pyplot as plt

# %% [markdown]
# ## Definiciones varias

# %%
class City:
    def __init__(self, x, y):
        self.x = x
        self.y = y
    
    def distance(self, city):
        xDis = abs(self.x - city.x)
        yDis = abs(self.y - city.y)
        distance = np.sqrt((xDis ** 2) + (yDis ** 2))
        return distance
    
    def __repr__(self):
        return "City(" + str(self.x) + "," + str(self.y) + ")"

class Fitness:
    def __init__(self, route):
        self.route = route
        self.distance = 0
        self.fitness = 0.0
    
    def routeDistance(self):
        if self.distance == 0:
            pathDistance = 0
            for i in range(0, len(self.route)):
                fromCity = self.route[i]
                toCity = None
                if i + 1 < len(self.route):
                    toCity = self.route[i + 1]
                else:
                    toCity = self.route[0]
                pathDistance += fromCity.distance(toCity)
            self.distance = pathDistance
        return self.distance
    
    def routeFitness(self):
        if self.fitness == 0:
            self.fitness = 1 / float(self.routeDistance())
        return self.fitness

# %%
# determine whether to stop a generation after x iterations of no improvement
def stop_gen(g, x):
    if g.generations_completed > x:
        max_index = g.generations_completed - 1
        curr_fitness = g.best_solutions_fitness[max_index]
        x_back_fitness = g.best_solutions_fitness[max_index - x]
        if math.isclose(curr_fitness, x_back_fitness, abs_tol=0.00003):
            return True
    return False

def print_route(route, title): 
    x_coordinates = [c.x for c in route] + [route[0].x]
    y_coordinates = [c.y for c in route] + [route[0].y]
    plt.scatter(x_coordinates, y_coordinates)
    plt.plot(x_coordinates, y_coordinates)
    plt.xlabel("x distance")
    plt.ylabel("y distance")
    plt.title(title)

class RunManager:
    def __init__(self, initial_population, generations):
        self.initial_population = initial_population
        self.generations = generations
    
    def fitness_func(self, route_raw, _):
        """Computes the fitness of a given route."""
        route = [self.initial_population[int(i)-1] for i in route_raw]
        return Fitness(route).routeFitness()

    def on_generation(self, g):
        """Call back on each generation run."""
        print(f"[{g.generations_completed+1}/{self.generations}] Current best route score: {round(1 / g.best_solutions_fitness[-1], 4)}")
        x = 500
        if stop_gen(g, x):
            return "stop"
        

# cityList = []
# for i in range(0, 20):
#     cityList.append(City(x=int(random.random() * 200), y=int(random.random() * 200)))

# run_manager = RunManager(cityList, 200)
# run_manager.fitness_func(range(len(cityList)), _)

# %% [markdown]
# ## Implicaciones de Distintas configuraciones del Algoritmo
#
# - Soluciones por población:
#     - Valores demasiado bajos resultand en un mínimos locales
#     - Valores demasiado altosaumento del tiempo de cálculo
#
# - Generaciones
#     - Si es muy bajo no se alcanza una meseta en la funcion de fitness => Esto implica que el algoritmo aun no encontró una solución óptima.
#     - Si es demasiado alto, el algotirmo sigue corriendo aun cuando ya no se encontraron más mejoras => tiempo de cálculo desperdiciado
#         - PyGAD permite definir [criterios de parada](https://pygad.readthedocs.io/en/latest/README_pygad_ReadTheDocs.html?#stop-criteria) para detener las corridas si se alcanza un óptimo.
#
# - Un menor número de padres que se aparean resulta en demasiado "elitismo":
#     - Al seleccionarse un pequeño subconjunto de padres, se reduce la diversidad y solo se obtienen los rasgos positivos de una pequeña porción de la población. No juega con las fortalezas del algoritmo genético.
#
# - La mutación adaptativa ayuda a arrancar el proceso y a reducir el espacio de soluciones más rápido:
#     - Uno de los problemas con la mutación aleatoria es que se descartan soluciones buenas demasiado rápido y no lo suficiente las mala. La mutación adaptativa tiene como objetivo resolver esto al tener un porcentaje de mutación mayor para todas las soluciones peores que el promedio y un porcentaje de mutación más bajo para todas las soluciones mejores que el promedio.

# %%
def geneticAlgorithm(population, popSize=250, eliteSize=..., mutationRate=..., mating_percent=25, keep_percent, generations=200):
    
    # assign the fitness function
    # fitness_function = trip_dist
    run_manager = RunManager(population, generations)

    # how many generations to iterate through
    # set this high and let the stop_gen funciton determine whether to end
    #  make sure to set the number of iterations in stop_gen sufficently high for your dataset
    # num_generations = 5000
    num_generations = generations

    # size of the population
    sol_per_pop = popSize

    # solution space
    num_genes = len(population)

    # solution range
    gene_space = range(1, len(population) + 1)

    # mate with the top x% of the population
    num_parents_mating = math.ceil(sol_per_pop * mating_percent / 100)

    # keep the top x% of the population for the next generation
    # 1% works good for larger population (>1000), else 5% is good
    keep_percent = 5
    keep_parents = math.ceil(sol_per_pop * keep_percent / 100)

    # choose how to select parents
    # parent_selection_type = "sss"
    parent_selection_type = "rank"

    # crossover the data from single point and two point was indistinguishable
    # but two point was more resource intensive
    crossover_type = "single_point"
    # crossover_type = "two_points"

    # how to implement mutation
    mutation_type = "adaptive"

    # will throw warning if percent * MAX_CITIES < 1 (i.e. in tsp1.csv)
    # [20, 5] has produced the best results
    mutation_percent_genes = [20, 5]

    # initialize the genetic algorithm parameters
    ga_instance = pygad.GA(
        num_generations=num_generations,
        num_parents_mating=num_parents_mating,
        # fitness_func=fitness_function,
        fitness_func = lambda route, _: run_manager.fitness_func(route, _),
        sol_per_pop=sol_per_pop,
        num_genes=num_genes,
        parent_selection_type=parent_selection_type,
        keep_parents=keep_parents,
        crossover_type=crossover_type,
        mutation_type=mutation_type,
        mutation_percent_genes=mutation_percent_genes,
        gene_space=gene_space,
        # on_generation=on_generation,
        on_generation=lambda g: run_manager.on_generation(g),
        allow_duplicate_genes=False,
        # parallel_processing=["thread", None],
    )

    # run an instance of the genetic algorithm
    ga_instance.run()
    return ga_instance

# %% [markdown]
# ## Main
#
# Runs the genetic algorithm and outputs the best solution found.

# %%
cityList = []
for i in range(0, 20):
    cityList.append(City(x=int(random.random() * 200), y=int(random.random() * 200)))

# %%
# %%time
ga_instance = geneticAlgorithm(population=cityList, popSize=10, generations=200)
# Out:
# [2/200] Current best route score: 1524.2184
# [3/200] Current best route score: 1524.2184
# [4/200] Current best route score: 1465.0204
# [5/200] Current best route score: 1462.1694
# [6/200] Current best route score: 1240.8659
# [7/200] Current best route score: 1240.8659
# [8/200] Current best route score: 1178.0215
# [9/200] Current best route score: 1178.0215
# [10/200] Current best route score: 1081.575
# [11/200] Current best route score: 1081.575
# [12/200] Current best route score: 1081.575
# [13/200] Current best route score: 1081.575
# [14/200] Current best route score: 1081.575
# [15/200] Current best route score: 1081.575
# [16/200] Current best route score: 1081.575
# [17/200] Current best route score: 1037.3674
# [18/200] Current best route score: 1037.3674
# [19/200] Current best route score: 1037.3674
# [20/200] Current best route score: 1003.3974
# [21/200] Current best route score: 1003.3974
# [22/200] Current best route score: 1003.3974
# [23/200] Current best route score: 1003.3974
# [24/200] Current best route score: 1003.3974
# [25/200] Current best route score: 1003.3974
# [26/200] Current best route score: 1003.3974
# [27/200] Current best route score: 1003.3974
# [28/200] Current best route score: 931.181
# [29/200] Current best route score: 931.181
# [30/200] Current best route score: 931.181
# [31/200] Current best route score: 931.181
# [32/200] Current best route score: 931.181
# [33/200] Current best route score: 931.181
# [34/200] Current best route score: 931.181
# [35/200] Current best route score: 931.181
# [36/200] Current best route score: 931.181
# [37/200] Current best route score: 931.181
# [38/200] Current best route score: 931.181
# [39/200] Current best route score: 931.181
# [40/200] Current best route score: 916.3951
# [41/200] Current best route score: 916.3951
# [42/200] Current best route score: 916.3951
# [43/200] Current best route score: 916.3951
# [44/200] Current best route score: 916.3951
# [45/200] Current best route score: 916.3951
# [46/200] Current best route score: 916.3951
# [47/200] Current best route score: 916.3951
# [48/200] Current best route score: 916.3951
# [49/200] Current best route score: 916.3951
# [50/200] Current best route score: 916.3951
# [51/200] Current best route score: 916.3951
# [52/200] Current best route score: 916.3951
# [53/200] Current best route score: 916.3951
# [54/200] Current best route score: 916.3951
# [55/200] Current best route score: 909.5735
# [56/200] Current best route score: 909.5735
# [57/200] Current best route score: 909.5735
# [58/200] Current best route score: 909.5735
# [59/200] Current best route score: 909.5735
# [60/200] Current best route score: 909.5735
# [61/200] Current best route score: 909.5735
# [62/200] Current best route score: 909.5735
# [63/200] Current best route score: 909.5735
# [64/200] Current best route score: 909.5735
# [65/200] Current best route score: 897.7707
# [66/200] Current best route score: 897.7707
# [67/200] Current best route score: 897.7707
# [68/200] Current best route score: 897.7707
# [69/200] Current best route score: 897.7707
# [70/200] Current best route score: 897.7707
# [71/200] Current best route score: 897.7707
# [72/200] Current best route score: 897.7707
# [73/200] Current best route score: 897.7707
# [74/200] Current best route score: 897.7707
# [75/200] Current best route score: 897.7707
# [76/200] Current best route score: 897.7707
# [77/200] Current best route score: 897.7707
# [78/200] Current best route score: 897.7707
# [79/200] Current best route score: 897.7707
# [80/200] Current best route score: 897.7707
# [81/200] Current best route score: 897.7707
# [82/200] Current best route score: 897.7707
# [83/200] Current best route score: 893.4709
# [84/200] Current best route score: 893.4709
# [85/200] Current best route score: 882.5026
# [86/200] Current best route score: 882.5026
# [87/200] Current best route score: 882.5026
# [88/200] Current best route score: 882.5026
# [89/200] Current best route score: 882.5026
# [90/200] Current best route score: 870.1123
# [91/200] Current best route score: 870.1123
# [92/200] Current best route score: 870.1123
# [93/200] Current best route score: 870.1123
# [94/200] Current best route score: 863.9015
# [95/200] Current best route score: 863.9015
# [96/200] Current best route score: 863.9015
# [97/200] Current best route score: 863.9015
# [98/200] Current best route score: 863.9015
# [99/200] Current best route score: 863.9015
# [100/200] Current best route score: 863.9015
# [101/200] Current best route score: 863.9015
# [102/200] Current best route score: 863.9015
# [103/200] Current best route score: 863.9015
# [104/200] Current best route score: 863.9015
# [105/200] Current best route score: 863.9015
# [106/200] Current best route score: 863.9015
# [107/200] Current best route score: 863.9015
# [108/200] Current best route score: 863.9015
# [109/200] Current best route score: 863.9015
# [110/200] Current best route score: 863.9015
# [111/200] Current best route score: 863.9015
# [112/200] Current best route score: 787.8975
# [113/200] Current best route score: 787.8975
# [114/200] Current best route score: 787.8975
# [115/200] Current best route score: 787.8975
# [116/200] Current best route score: 787.8975
# [117/200] Current best route score: 787.8975
# [118/200] Current best route score: 787.8975
# [119/200] Current best route score: 787.8975
# [120/200] Current best route score: 764.0193
# [121/200] Current best route score: 764.0193
# [122/200] Current best route score: 764.0193
# [123/200] Current best route score: 764.0193
# [124/200] Current best route score: 764.0193
# [125/200] Current best route score: 764.0193
# [126/200] Current best route score: 764.0193
# [127/200] Current best route score: 764.0193
# [128/200] Current best route score: 764.0193
# [129/200] Current best route score: 764.0193
# [130/200] Current best route score: 764.0193
# [131/200] Current best route score: 764.0193
# [132/200] Current best route score: 729.4957
# [133/200] Current best route score: 729.4957
# [134/200] Current best route score: 729.4957
# [135/200] Current best route score: 729.4957
# [136/200] Current best route score: 729.4957
# [137/200] Current best route score: 729.4957
# [138/200] Current best route score: 729.4957
# [139/200] Current best route score: 729.4957
# [140/200] Current best route score: 729.4957
# [141/200] Current best route score: 729.4957
# [142/200] Current best route score: 729.4957
# [143/200] Current best route score: 729.4957
# [144/200] Current best route score: 729.4957
# [145/200] Current best route score: 711.5984
# [146/200] Current best route score: 711.5984
# [147/200] Current best route score: 711.5984
# [148/200] Current best route score: 711.5984
# [149/200] Current best route score: 711.5984
# [150/200] Current best route score: 711.5984
# [151/200] Current best route score: 711.5984
# [152/200] Current best route score: 711.5984
# [153/200] Current best route score: 711.5984
# [154/200] Current best route score: 711.5984
# [155/200] Current best route score: 711.5984
# [156/200] Current best route score: 711.5984
# [157/200] Current best route score: 711.5984
# [158/200] Current best route score: 711.5984
# [159/200] Current best route score: 711.5984
# [160/200] Current best route score: 711.5984
# [161/200] Current best route score: 711.5984
# [162/200] Current best route score: 711.5984
# [163/200] Current best route score: 711.5984
# [164/200] Current best route score: 711.5984
# [165/200] Current best route score: 711.5984
# [166/200] Current best route score: 711.5984
# [167/200] Current best route score: 711.5984
# [168/200] Current best route score: 711.5984
# [169/200] Current best route score: 711.5984
# [170/200] Current best route score: 711.5984
# [171/200] Current best route score: 711.5984
# [172/200] Current best route score: 711.5984
# [173/200] Current best route score: 711.5984
# [174/200] Current best route score: 711.5984
# [175/200] Current best route score: 711.5984
# [176/200] Current best route score: 711.5984
# [177/200] Current best route score: 711.5984
# [178/200] Current best route score: 711.5984
# [179/200] Current best route score: 711.5984
# [180/200] Current best route score: 711.5984
# [181/200] Current best route score: 711.5984
# [182/200] Current best route score: 711.5984
# [183/200] Current best route score: 711.5984
# [184/200] Current best route score: 711.5984
# [185/200] Current best route score: 711.5984
# [186/200] Current best route score: 711.5984
# [187/200] Current best route score: 711.5984
# [188/200] Current best route score: 711.5984
# [189/200] Current best route score: 711.5984
# [190/200] Current best route score: 711.5984
# [191/200] Current best route score: 711.5984
# [192/200] Current best route score: 711.5984
# [193/200] Current best route score: 711.5984
# [194/200] Current best route score: 711.5984
# [195/200] Current best route score: 711.5984
# [196/200] Current best route score: 711.5984
# [197/200] Current best route score: 711.5984
# [198/200] Current best route score: 706.0331
# [199/200] Current best route score: 706.0331
# [200/200] Current best route score: 706.0331
# [201/200] Current best route score: 706.0331
# CPU times: user 717 ms, sys: 19.4 ms, total: 736 ms
# Wall time: 731 ms

# %%
_ = ga_instance.plot_fitness()

# %%
   
bestRoute = [
    cityList[i-1] for i in ga_instance.best_solution()[0].astype(int)
]
print_route(cityList, "Intial Solution Route")
plt.show()
print_route(bestRoute, "Best Solution Route")
plt.show()

# %% [markdown]
# # References
#
# * https://github.com/mstpn/PyGAD_TSP/blob/main/PyGAD_TSP.ipynb
